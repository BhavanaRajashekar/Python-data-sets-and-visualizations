# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavanaRajashekar/Analysing-TV-data-in-python/blob/main/IPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/BhavanaRajashekar/Dataset1/main/t20_matches.csv")

# %%
data
# Out:
#       match_id  series_id                                      match_details  \
# 0       304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1       129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2       129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3       304745     124121  South Group:Surrey v Middlesex at The Oval- Ju...
# 4       304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# ...        ...        ...                                                ...
# 6412   1083450    1083439  2nd T20I:Sri Lanka v Bangladesh at Colombo (RP...
# 6413   1082591    1078425  1st match:Sunrisers Hyderabad v Royal Challeng...
# 6414   1082592    1078425  2nd match:Rising Pune Supergiant v Mumbai Indi...
# 6415   1082593    1078425  3rd match:Gujarat Lions v Kolkata Knight Rider...
# 6416   1082594    1078425  4th match:Kings XI Punjab v Rising Pune Superg...
#
# ...

# %%
data.head(10)
# Out:
#    match_id  series_id                                      match_details  \
# 0    304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1    129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2    129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3    304745     124121  South Group:Surrey v Middlesex at The Oval- Ju...
# 4    304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# 5    304747     124121  Midlands/Wales/West Group:Gloucestershire v Wo...
# 6    304748     124121  South Group:Surrey v Essex at East Molesey- Ju...
# 7    304749     124121  North Group:Yorkshire v Derbyshire at Leeds- J...
# 8    304750     124121  Midlands/Wales/West Group:Glamorgan v Northamp...
# 9    129665     124121  South Group:Kent v Hampshire at Beckenham- Jun...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# ...

# %%
data.describe()
# Out:
#            match_id     series_id  win_by_runs  win_by_wickets  \
# count  6.417000e+03  6.417000e+03  2931.000000     3004.000000
# mean   6.000441e+05  5.879816e+05    31.320710        6.089214
# std    2.302316e+05  2.387841e+05    26.838237        1.996341
# min    1.295970e+05  1.241210e+05     1.000000        1.000000
# 25%    4.249410e+05  4.200050e+05    11.000000        5.000000
# 50%    5.673530e+05  5.642800e+05    24.000000        6.000000
# 75%    7.760790e+05  7.754450e+05    45.000000        8.000000
# max    1.085496e+06  1.083439e+06   172.000000       10.000000
#
#        balls_remaining  innings1_runs  innings1_wickets  \
# count      2969.000000    6151.000000       6151.000000
# mean         13.978107     151.409527          6.577630
# std          14.664918      32.986924          2.152355
# min           0.000000       1.000000          0.000000
# 25%           4.000000     131.000000          5.000000
# 50%           9.000000     152.000000          7.000000
# ...

# %%
data.shape
# Out:
# (6417, 26)

# %%
data['home'].unique
# Out:
# <bound method Series.unique of 0                       Durham
# 1                    Hampshire
# 2                     Somerset
# 3                       Surrey
# 4               Worcestershire
#                  ...
# 6412                 Sri Lanka
# 6413       Sunrisers Hyderabad
# 6414    Rising Pune Supergiant
# 6415             Gujarat Lions
# 6416           Kings XI Punjab
# Name: home, Length: 6417, dtype: object>

# %%
ipl = data[(data['home'] == 'Sunrisers Hyderabad') | (data['home'] == 'Kings XI Punjab') | (data['home'] == 'Mumbai Indians')
                | (data['home'] == 'Royal Challengers Bangalore') | (data['home'] == 'Kolkatta Knight Riders')
                | (data['home'] == 'Chennai Super Kings')].copy()

# %%
ipl
# Out:
#       match_id  series_id                                      match_details  \
# 897     335982     313494  1st match:Royal Challengers Bangalore v Kolkat...
# 898     335983     313494  2nd match:Kings XI Punjab v Chennai Super King...
# 901     335985     313494  5th match:Mumbai Indians v Royal Challengers B...
# 904     335989     313494  8th match:Chennai Super Kings v Mumbai Indians...
# 906     335991     313494  10th match:Kings XI Punjab v Mumbai Indians at...
# ...        ...        ...                                                ...
# 5890    980999     968923  50th match:Royal Challengers Bangalore v Kings...
# 5898    981015     968923  Eliminator:Sunrisers Hyderabad v Kolkata Knigh...
# 5900    981019     968923  Final:Royal Challengers Bangalore v Sunrisers ...
# 6413   1082591    1078425  1st match:Sunrisers Hyderabad v Royal Challeng...
# 6416   1082594    1078425  4th match:Kings XI Punjab v Rising Pune Superg...
#
# ...

# %%
ipl = ipl.set_index(['date'])

# %%
ipl.drop(['match_id', 'series_id'], axis = 1, inplace=True)

# %%
ipl.head()
# Out:
#                                                 match_details  \
# date
# 18/04/2008  1st match:Royal Challengers Bangalore v Kolkat...
# 19/04/2008  2nd match:Kings XI Punjab v Chennai Super King...
# 20/04/2008  5th match:Mumbai Indians v Royal Challengers B...
# 23/04/2008  8th match:Chennai Super Kings v Mumbai Indians...
# 25/04/2008  10th match:Kings XI Punjab v Mumbai Indians at...
#
#                                                        result  \
# date
# 18/04/2008              Kolkata Knight Riders won by 140 runs
# 19/04/2008                 Chennai Super Kings won by 33 runs
# 20/04/2008  Royal Challengers Bangalore won by 5 wickets (...
# 23/04/2008                  Chennai Super Kings won by 6 runs
# 25/04/2008                     Kings XI Punjab won by 66 runs
#
#                                                        scores      venue  \
# date
# 18/04/2008  Kolkata Knight Riders 222/3 (20/20 ov); Royal ...  Bangalore
# ...

# %%
ipl['winner'].value_counts()
# Out:
# Chennai Super Kings                      75
# Mumbai Indians                           67
# Royal Challengers Bangalore              57
# Kings XI Punjab                          47
# Sunrisers Hyderabad                      26
# Kolkata Knight Riders                    19
# Rajasthan Royals                         15
# Delhi Daredevils                         13
# Deccan Chargers                          10
# Match abandoned without a ball bowled     5
# No result                                 4
# Pune Warriors                             3
# New South Wales                           2
# Rising Pune Supergiants                   2
# Sydney Sixers                             2
# Trinidad & Tobago                         2
# Gujarat Lions                             2
# South Australia                           2
# Victoria                                  2
# Warriors                                  1
# No result (abandoned with a toss)         1
# ...

# %%
ipl['win_by_runs'].count()
# Out:
# 172

# %%
ipl['win_by_wickets'].count()
# Out:
# 175

# %%
teams = ['Sunrisers Hyderabad', 'Kings XI Punjab', 'Mumbai Indians', 'Royal Challengers Bangalore', 'Kolkatta Knight Riders', 'Chennai Super Kings']

# %%
ipl.columns
# Out:
# Index(['match_details', 'result', 'scores', 'venue', 'round', 'home', 'away',
#        'winner', 'win_by_runs', 'win_by_wickets', 'balls_remaining',
#        'innings1', 'innings1_runs', 'innings1_wickets',
#        'innings1_overs_batted', 'innings1_overs', 'innings2', 'innings2_runs',
#        'innings2_wickets', 'innings2_overs_batted', 'innings2_overs',
#        'D/L_method', 'target'],
#       dtype='object')

# %%
ipl.rename(columns={'win_by_runs': 'Win-Batted First', 'win_by_wickets': 'Win-Bowled First'}, inplace=True)
